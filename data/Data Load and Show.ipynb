# %%
import numpy as np
import ImShow as I
import matplotlib.pyplot as plt
from collections import Counter

# %% [markdown]
# #### .txt file and .npk file contain the same data
# .npk file is created by numpy of python2 which can not be loaded by numpy of python3. <br>
# .txt file can be loaded by both python2 and python2, but loading is slower than .npk

# %%
data = np.load("data.npk")
y = np.load("y.npk")
print data.shape
print y.shape
print Counter(y.reshape(y.size))
# Out:
# (5124, 784)
# (5124,)
# Counter({4: 4859, 0: 35, 7: 34, 9: 34, 2: 29, 5: 28, 6: 28, 8: 27, 1: 25, 3: 25})

# %%
Xpic = I.tile_raster_images(X = data, img_shape=(28,28), tile_shape=(10,10))
plt.imshow(Xpic,cmap='gray')
plt.show()

# %%
data = np.loadtxt("data.txt",delimiter=",")
y = np.loadtxt("y.txt",delimiter=",")
print data.shape
print y.shape
print Counter(y.reshape(y.size))
# Out:
# (5124, 784)
# (5124,)
# Counter({4.0: 4859, 0.0: 35, 7.0: 34, 9.0: 34, 2.0: 29, 5.0: 28, 6.0: 28, 8.0: 27, 1.0: 25, 3.0: 25})

# %%
Xpic = I.tile_raster_images(X = data, img_shape=(28,28), tile_shape=(10,10))
plt.imshow(Xpic,cmap='gray')
plt.show()
